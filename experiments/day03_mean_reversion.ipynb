# %%
import sys
sys.path.append("../src/python")  # so Python can see the package

from strategies.zscore_strategy import backtest_zscore_strategy

asset = "AAPL"
r = returns[asset].dropna()
equity, strat_ret_tc, stats = backtest_zscore_strategy(r)

print(stats)
equity.plot(figsize=(10,4), title=f"Equity – {asset} Z-score Strategy")
# Out:
# {'mean_return': np.float64(-0.0005824076040341261), 'volatility': 0.012416964386444799, 'sharpe': np.float64(-0.7445808656563918)}
# <Axes: title={'center': 'Equity – AAPL Z-score Strategy'}, xlabel='Date'>

# %% [markdown]
# #### Interpret:
#
# Negative Sharpe means:
# - Your average returns are negative (you are losing money)
# - While still taking on volatility (risk)
